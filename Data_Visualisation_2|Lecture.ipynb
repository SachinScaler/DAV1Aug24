# %% [markdown]
# <a href="https://colab.research.google.com/github/SachinScaler/DAV1Aug24/blob/main/Data_Visualisation_2%7CLecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Downloading the Tencent Games dataset

# %%
# !gdown https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166 -O final_vg.csv
# Out:
# Downloading...
# From: https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166
# To: /content/final_vg.csv
# 100% 2.04M/2.04M [00:00<00:00, 16.7MB/s]

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/SachinScaler/DAV1Aug24/main/final_vg.csv')

# %%
df = pd.read_csv('/content/final_vg.csv')
df.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16652 entries, 0 to 16651
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16652 non-null  int64
#  1   Name          16652 non-null  object
#  2   Platform      16652 non-null  object
#  3   Year          16381 non-null  float64
#  4   Genre         16652 non-null  object
#  5   Publisher     16594 non-null  object
#  6   NA_Sales      16652 non-null  float64
#  7   EU_Sales      16652 non-null  float64
#  8   JP_Sales      16652 non-null  float64
#  9   Other_Sales   16652 non-null  float64
#  10  Global_Sales  16652 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df['Rank'].value_counts()
# Out:
# Rank
# 3012     15
# 4149     11
# 134       7
# 3013      3
# 3011      2
#          ..
# 5218      1
# 6015      1
# 8473      1
# 5944      1
# 12919     1
# Name: count, Length: 16598, dtype: int64

# %%
df['Year'].value_counts()
# Out:
# Year
# 2009.0    1432
# 2008.0    1429
# 2010.0    1261
# 2007.0    1204
# 2011.0    1140
# 2006.0    1009
# 2005.0     943
# 2002.0     830
# 2003.0     777
# 2004.0     765
# 2012.0     659
# 2015.0     615
# 2014.0     584
# 2013.0     548
# 2001.0     483
# 1998.0     380
# 2000.0     350
# 2016.0     345
# 1999.0     339
# 1997.0     291
# 1996.0     264
# 1995.0     221
# 1994.0     122
# 1993.0      61
# 1981.0      47
# 1992.0      45
# 1991.0      42
# 1982.0      37
# 1986.0      22
# 1989.0      18
# 1983.0      18
# 1990.0      17
# 1987.0      17
# 1985.0      16
# 1984.0      15
# 1988.0      15
# 1980.0      10
# 2017.0       5
# 2019.0       2
# 2020.0       2
# 2018.0       1
# Name: count, dtype: int64

# %%
len(df['Year'].value_counts())
# Out:
# 41

# %%
df.shape
# Out:
# (16652, 11)

# %%
df['NA_Sales'].value_counts()
# Out:
# NA_Sales
# 1.493442    1083
# 1.087977    1024
# 2.186589     574
# 0.394830     541
# 2.004268     530
#             ...
# 6.355835       1
# 6.391282       1
# 6.757858       1
# 4.672678       1
# 6.252763       1
# Name: count, Length: 862, dtype: int64

# %%
df['Name'].value_counts() # categorical nominal
# Out:
# Name
# Ice Hockey                                       41
# Baseball                                         17
# Need for Speed: Most Wanted                      12
# Ratatouille                                       9
# FIFA 14                                           9
#                                                  ..
# Indy 500                                          1
# Indy Racing 2000                                  1
# Indycar Series 2005                               1
# inFAMOUS                                          1
# Zyuden Sentai Kyoryuger: Game de Gaburincho!!     1
# Name: count, Length: 11493, dtype: int64

# %% [markdown]
# - Cols like: platform, genre, year etc are Categoricals
#     - Year is Ordinal
#     - Platform and Genre are Nominal
# - cols like: Global Sales, NA_Sales etc are continous

# %% [markdown]
# ### Introduction to Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# Let's say we want to draw a curve passing through 3 points:
#
# - (0, 3)
# - (1, 5)
# - (2, 9)

# %%
x = [0, 1, 2] # list, numpy or a Series
y = [3, 5, 9] # list, numpy or a Series

# %%
plt.plot(x, y) # this return some metadata about plot
plt.show() # doesn't return metadata, only plot
# positive: postive correlation

# %%
y = [6, 5, 1] # list, numpy or a Series
x = [1, 2, 4] # list, numpy or a Series
plt.plot(x, y) # this return some metadata about plot
plt.show() # doesn't return metadata, only plot
# Negative Trend: Negative correlation

# %% [markdown]
# plt.plot-> Plots a line chart using x and y values

# %%
plt.plot(x, y)
plt.title("Simple Line Chart")
plt.legend(['Blue'])
plt.show()

# %% [markdown]
# ### Barchart

# %%
df['Genre'].value_counts()
# Out:
# Genre
# Action          3316
# Sports          2400
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: count, dtype: int64

# %%
df['Genre'].value_counts().index
# Out:
# Index(['Action', 'Sports', 'Misc', 'Role-Playing', 'Shooter', 'Adventure',
#        'Racing', 'Platform', 'Simulation', 'Fighting', 'Strategy', 'Puzzle'],
#       dtype='object', name='Genre')

# %%
df['Genre'].value_counts().values
# Out:
# array([3316, 2400, 1739, 1488, 1310, 1286, 1249,  886,  867,  848,  681,
#         582])

# %%
x_bar = df['Genre'].value_counts().index
y_bar = df['Genre'].value_counts().values

# %%
plt.bar(x_bar, y_bar)
plt.show()

# %%
# figsize = (row-width, col-width)
plt.figure(figsize = (12, 8))
plt.bar(x_bar, y_bar)
plt.show()

# %%
plt.figure(figsize = (12, 8))
plt.bar(x_bar, y_bar)
plt.xticks(rotation=45, fontsize=12)
plt.xlabel("Genre")
plt.show()

# %% [markdown]
# #### Customize y axis as well

# %%
plt.figure(figsize = (12, 8))
plt.bar(x_bar, y_bar, width=0.5)
plt.xticks(rotation=45, fontsize=12)
plt.xlabel("Genre")
plt.show()

# %% [markdown]
# Seaborn:

# %%
plt.figure(figsize = (12, 8))

sns.countplot(x='Genre', data=df)
plt.xticks(rotation=45, fontsize=12)
plt.xlabel("Genre")
plt.show()

# %% [markdown]
# ### HW:
# - Sort the index in seaborn chart
# - Find function to ser color of bars in both matplotlib and seaborn respectively
# - Check of pie chart and convert above barchart into pie charts with % instead of exact counts

# %% [markdown]
# ### Pie Chart

# %%
df.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
sales_data = df[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]
region_sales = sales_data.T.sum(axis = 1)
region_sales
# Out:
# NA_Sales       45831.525845
# EU_Sales       33251.970702
# JP_Sales       41624.625635
# Other_Sales    19180.256828
# dtype: float64

# %%
sales_data.T
# Out:
#                 0         1         2         3         4         5      \
# NA_Sales     4.569217  2.076955  1.145709  2.031986  2.792725  2.456509
# EU_Sales     3.033887  1.493442  1.762339  1.389856  2.592054  1.435228
# JP_Sales     3.439352  3.033887  1.493442  3.228043  1.440483  3.167419
# Other_Sales  1.991671  0.394830  0.408693  0.394830  1.493442  0.471076
#
#                 6         7         8         9      ...     16642     16643  \
# NA_Sales     2.031986  4.286650  2.076955  3.530324  ...  5.553885  3.727034
# EU_Sales     1.389856  4.032416  1.493442  3.285202  ...  4.266031  3.439352
# JP_Sales     3.228043  3.652926  3.033887  3.390562  ...  1.143442  2.766445
# Other_Sales  0.394830  2.959779  0.394830  2.186589  ...  3.285202  2.592054
#
#                 16644     16645     16646     16647     16648     16649  \
# NA_Sales     5.431782  2.648962  2.872173  4.409308  3.033887  3.228043
# EU_Sales     5.067659  2.340740  2.186589  3.167419  2.792725  2.004268
# ...

# %%
plt.pie(region_sales,
        labels=region_sales.index,
        autopct='%.f%%',
        explode=[0.1, 0.1, 0.1, 0.05]
        )
plt.show()

# %%
### PLOT GENRE WISE SUM OF NA_SALES

# %% [markdown]
# # next session
# - scatter
# - hist
# - boxplot

# %%
df.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
plt.hist(df['NA_Sales'])
plt.show()

# %%
plt.hist(df['NA_Sales'], bins=4)
plt.show()

# %%
sns.histplot(df['NA_Sales'], bins=10)
plt.show()

# %%
sns.histplot(df['Year'], bins=10)
plt.show()

# %%
df['Year'].value_counts()
# Out:
# Year
# 2009.0    1432
# 2008.0    1429
# 2010.0    1261
# 2007.0    1204
# 2011.0    1140
# 2006.0    1009
# 2005.0     943
# 2002.0     830
# 2003.0     777
# 2004.0     765
# 2012.0     659
# 2015.0     615
# 2014.0     584
# 2013.0     548
# 2001.0     483
# 1998.0     380
# 2000.0     350
# 2016.0     345
# 1999.0     339
# 1997.0     291
# 1996.0     264
# 1995.0     221
# 1994.0     122
# 1993.0      61
# 1981.0      47
# 1992.0      45
# 1991.0      42
# 1982.0      37
# 1986.0      22
# 1989.0      18
# 1983.0      18
# 1990.0      17
# 1987.0      17
# 1985.0      16
# 1984.0      15
# 1988.0      15
# 1980.0      10
# 2017.0       5
# 2019.0       2
# 2020.0       2
# 2018.0       1
# Name: count, dtype: int64

# %% [markdown]
# ### KDE PLOT
# - Continous probability Density
#
# - POST READ:
#     - https://en.wikipedia.org/wiki/Kernel_density_estimation
#     - https://www.youtube.com/watch?v=DCgPRaIDYXA

# %%
sns.histplot(df['Year'], bins=10)
plt.show()

# %%
sns.kdeplot(df['Year'])
plt.show()

# %% [markdown]
# ### BOXPLOT: Continous Univariate
# - Minimum score
# - First (lower) quartile
# - Median
# - Third (upper) quartile
# Maximum score
# - outliers

# %%
df.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
plt.figure(figsize = (4,8))
sns.boxplot(df['Global_Sales'])
plt.show()

# %%
plt.figure(figsize = (4,8))
sns.boxplot(df['NA_Sales'])
plt.show()

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16652.000000  16381.000000  16652.000000  16652.000000  16652.000000
# mean    8283.409620   2006.390513      2.752314      1.996875      2.499677
# std     4794.471477      5.863261      1.327002      1.322972      1.164023
# min        1.000000   1980.000000      0.140000      0.010000      0.000000
# 25%     4129.750000   2003.000000      1.781124      1.087977      1.781124
# 50%     8273.500000   2007.000000      2.697415      1.714664      2.480356
# 75%    12436.250000   2010.000000      3.677290      2.795123      3.176299
# max    16600.000000   2020.000000      8.725452      8.367985     12.722984
#
#         Other_Sales  Global_Sales
# count  16652.000000  16652.000000
# mean       1.151829      8.457873
# std        1.054813      3.717756
# min       -0.474276      0.240000
# 25%        0.394830      5.580341
# 50%        0.491870      7.536614
# 75%        1.781124     11.227334
# ...

# %%
plt.figure(figsize = (4,8))
sns.boxplot(df['Other_Sales'])
plt.show()

# %% [markdown]
# ### Bi-Variate
# - Continuous-Continuous

# %% [markdown]
# - Line Plot

# %%
# Let's see if a particular sales is increasing or decreasing

# %%
df.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
game = 'Ice Hockey'
df_sub = df.loc[df['Name']==game]

# %%
sns.lineplot(x='Year', y='NA_Sales', data=df_sub)
plt.show()

# %%
df_sub['NA_Sales']
# Out:
# 6073    0.44
# 6074    0.39
# 6075    0.61
# 6076    0.65
# 6077    0.68
# 6078    0.75
# 6079    0.78
# 6080    0.76
# 6081    0.82
# 6082    0.88
# 6083    0.85
# 6084    0.84
# 6085    0.87
# 6086    0.90
# 6087    0.70
# 6088    0.60
# 6089    0.63
# 6090    0.57
# 6091    0.58
# 6092    0.49
# 6093    0.40
# 6094    0.43
# 6095    0.42
# 6096    0.40
# 6097    0.41
# 6098    0.45
# 6099    0.35
# 6100    0.38
# 6101    0.30
# 6102    0.20
# 6103    0.19
# 6104    0.14
# 6105    0.60
# 6106    0.40
# 6107    0.52
# 6108    0.58
# 6109    0.60
# 6110    0.48
# 6111    0.45
# 6112    0.45
# 6113    0.53
# Name: NA_Sales, dtype: float64

# %%
sns.lineplot(x='Year', y='NA_Sales', data=df_sub)
plt.xlim(left=1995, right=2005)
plt.show()

# %%
game = 'Baseball'
df_sub = df.loc[df['Name']==game]
sns.lineplot(x='Year', y='NA_Sales', data=df_sub)
plt.show()

# %%
game1 = 'Ice Hockey'
df_sub = df.loc[df['Name']==game1]
sns.lineplot(x='Year', y='NA_Sales', data=df_sub)

game2 = 'Baseball'
df_sub = df.loc[df['Name']==game2]
sns.lineplot(x='Year', y='NA_Sales', data=df_sub)
plt.show()

# %% [markdown]
# ### Add legend in this chart

# %% [markdown]
# resume@8:20

# %%
game1 = 'Ice Hockey'
df_sub = df.loc[df['Name']==game1]
sns.lineplot(x='Year', y='NA_Sales', data=df_sub)

game2 = 'Baseball'
df_sub = df.loc[df['Name']==game2]
sns.lineplot(x='Year', y='NA_Sales', data=df_sub)
plt.legend([game1, game2])
plt.show()

# bug in colab: legends are not shown properly

# %%
game1 = 'Ice Hockey'
df_sub = df.loc[df['Name']==game1]
sns.lineplot(x='Year', y='NA_Sales', data=df_sub, label=game1)

game2 = 'Baseball'
df_sub = df.loc[df['Name']==game2]
sns.lineplot(x='Year', y='NA_Sales', data=df_sub, label=game2)
plt.legend()
plt.show()

# %%
game1 = 'Ice Hockey'
df_sub = df.loc[df['Name']==game1]
sns.lineplot(x='Year', y='NA_Sales', data=df_sub, label=game1)

game2 = 'Baseball'
df_sub = df.loc[df['Name']==game2]
sns.lineplot(x='Year', y='NA_Sales', data=df_sub, label=game2)
plt.legend(loc='upper left')
plt.show()

# %%
game1 = 'Ice Hockey'
df_sub = df.loc[df['Name']==game1]
sns.lineplot(x='Year', y='NA_Sales', data=df_sub, label=game1)

game2 = 'Baseball'
df_sub = df.loc[df['Name']==game2]
sns.lineplot(x='Year', y='NA_Sales', data=df_sub, label=game2)
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %% [markdown]
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.grid.html

# %%
game1 = 'Ice Hockey'
df_sub = df.loc[df['Name']==game1]
df_sub['NA_Sales'].argmax()
# Out:
# 13

# %%
df_sub.iloc[13].Year, df_sub.iloc[13].NA_Sales
# Out:
# (2002.0, 0.9)

# %%
game1 = 'Ice Hockey'
df_sub = df.loc[df['Name']==game1]
sns.lineplot(x='Year', y='NA_Sales', data=df_sub, label=game1)


# specify any point as x,y,label
plt.text(2002, 0.9, 'Max Ice Hockey Sale')

game2 = 'Baseball'
df_sub = df.loc[df['Name']==game2]
sns.lineplot(x='Year', y='NA_Sales', data=df_sub, label=game2)
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
df[['Rank', 'Global_Sales']]
# Out:
#         Rank  Global_Sales
# 0       2061     12.802935
# 1       9137      7.034163
# 2      14279      4.982552
# 3       8359      7.226880
# 4       7109      8.363113
# ...      ...           ...
# 16647   7925     13.053204
# 16648   6279      8.878837
# 16649   6977      7.954274
# 16650  15422      3.509168
# 16651  12919      5.132196
#
# [16652 rows x 2 columns]

# %%
plt.figure(figsize = (12, 8))

sns.lineplot(x='Rank', y='Global_Sales', data=df)
plt.show()

# %%
plt.figure(figsize = (12, 8))
sns.scatterplot(x='Rank', y='Global_Sales', data=df)
plt.show()

# %%
plt.figure(figsize = (12, 8))
sns.scatterplot(x='Rank', y='NA_Sales', data=df)
plt.show()

# %% [markdown]
# ### Filter Some Data and select only top 3 publishers, Genres and Platform

# %%
top3_pub = df['Publisher'].value_counts().index[:3]
top3_gen = df['Genre'].value_counts().index[:3]
top3_plat = df['Platform'].value_counts().index[:3]

# %%
top3_data = df.loc[(df["Publisher"].isin(top3_pub)) & (df["Platform"].isin(top3_plat)) & (df['Genre'].isin(top3_gen))]
top3_data
# Out:
#         Rank                                               Name Platform  \
# 2      14279                  .hack: Sekai no Mukou ni + Versus      PS3
# 13      2742                                      [Prototype 2]      PS3
# 16      1604                                        [Prototype]      PS3
# 19      1741                             007: Quantum of Solace      PS3
# 21      4501                             007: Quantum of Solace      PS2
# ...      ...                                                ...      ...
# 16438  14938  Yes! Precure 5 Go Go Zenin Shu Go! Dream Festival       DS
# 16479  10979                              Young Justice: Legacy      PS3
# 16601  11802                         ZhuZhu Pets: Quest for Zhu       DS
# 16636   9196                           Zoobles! Spring to Life!       DS
# 16640   9816                                               Zubo       DS
#
#          Year   Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ### Cat - Cat

# %%
sns.countplot(x='Publisher', data = top3_data)
# Out:
# <Axes: xlabel='Publisher', ylabel='count'>

# %% [markdown]
# Dodged Plot

# %%
sns.countplot(x='Publisher', hue = 'Platform',data = top3_data)
# Out:
# <Axes: xlabel='Publisher', ylabel='count'>

# %%
sns.countplot(x='Publisher', hue='Genre',data = top3_data)
# Out:
# <Axes: xlabel='Publisher', ylabel='count'>

# %%
# stacked plot

# %%
df_stacked_plot = pd.crosstab(index=top3_data['Publisher'],
                              columns=top3_data['Genre'])
df_stacked_plot
# Out:
# Genre               Action  Misc  Sports
# Publisher
# Activision             102    47      45
# Electronic Arts         59    18     186
# Namco Bandai Games     100    48      12

# %%
df_stacked_plot.plot(kind='bar', stacked = True)
# Out:
# <Axes: xlabel='Publisher'>

# %% [markdown]
# ### Con - Cat

# %%
df[['Publisher', 'NA_Sales']].head()
# Out:
#             Publisher  NA_Sales
# 0              Capcom  4.569217
# 1           505 Games  2.076955
# 2  Namco Bandai Games  1.145709
# 3  Namco Bandai Games  2.031986
# 4  Namco Bandai Games  2.792725

# %%
sns.boxplot(x='Publisher', y='Global_Sales', data=top3_data)
# Out:
# <Axes: xlabel='Publisher', ylabel='Global_Sales'>

# %% [markdown]
# ### Do line chart for top3 publishers to comapres across NA_sales

# %%
sns.barplot(x='Publisher', y='NA_Sales',
            data=top3_data,
            estimator='sum' )
# Out:
# <Axes: xlabel='Publisher', ylabel='NA_Sales'>

# %% [markdown]
# ### What does the blackline

# %%
sns.barplot(x='Publisher', y='NA_Sales',
            data=top3_data,
            estimator='max' )
# Out:
# <Axes: xlabel='Publisher', ylabel='NA_Sales'>

# %%
### Subplots and axes

# %%
df.iloc[[3]].isna().sum().sum() # 0: sum_val

# %%
df.iloc[3].isna().sum() # sum of missing vals in a row

# %%
df_sub = df[['Rank', 'Year']]
df_sub.iloc[3].isna().sum()

# %%
df_sub.iloc[[3]].isna().sum().sum()

# %%
# fillna doc: dictionary
dict1= {'rank': 1000, 'Year': 1992}
df.fillna(value=dict1)

# %%
df['year'].fillna(1992)

# %%
mask = df['date'] = 'dateval'
f_df = df[mask]
len(set(d_df['customer'])), len(d_df['customer'].value_counts), d_df['customer'].nunique()

# %%
df['pickup'] = pd.to_datetime(df['pickup'])
df['dropoff'] = pd.to_datetime(df['dropoff'])
# Create a new column 'time_of_day'
df['time_of_day'] = '' df df.loc[(df['pickup'].dt.hour >= 0) AND (df['pickup'].dt.hour < 6), 'time_of_day'] = 'morning'
# df.loc[(df['pickup'].dt.hour >= 6) AND (df['pickup'].dt.hour < 12), 'time_of_day'] = 'day'
df.loc[(df['pickup'].dt.hour >= 12) AND (df['pickup'].dt.hour < 18), 'time_of_day'] = 'afternoon'
df.loc[(df['pickup'].dt.hour >= 18) AND (df['pickup'].dt.hour <= 24), 'time_of_day'] = 'night'
df_new=df.groupby(['time_of_day']).size().sort_values(ascending=False)
df_new

# %%
from datetime import datetime
def solve(A):
    day_suffixes = {'st', 'nd', 'rd', 'th'}
    for suffix in day_suffixes:
        if suffix in A:
            A = A.replace(suffix, '')
            break
    parsed_date = datetime.strptime(A, '%d %b %Y')
    return parsed_date.strftime('%Y-%m-%d')

solve('31th Apr 1951')

# %% [markdown]
# day: 0

# %%
2nd-May-2005 # split slice and map
['2nd', 'May', '2005']

# %% [markdown]
# Steps for given data:
# - EDA: Analysis of Dist and columns
# - Train-test split
# - decide outlier detection, null-value processing etc on Train-set
# - apply on test-set
