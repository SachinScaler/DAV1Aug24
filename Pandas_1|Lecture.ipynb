# %% [markdown]
# <a href="https://colab.research.google.com/github/SachinScaler/DAV1Aug24/blob/main/Pandas_1%7CLecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas # command line terminal remove !

# %%
import pandas as pd

# %%
# !wget "https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_" -O mckinsey.csv
# Out:
# --2024-08-27 01:43:59--  https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Resolving drive.google.com (drive.google.com)... 74.125.137.101, 74.125.137.139, 74.125.137.102, ...
# Connecting to drive.google.com (drive.google.com)|74.125.137.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download [following]
# --2024-08-27 01:43:59--  https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.137.132, 2607:f8b0:4023:c03::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.137.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 83785 (82K) [application/octet-stream]
# Saving to: ‘mckinsey.csv’
#
# ...

# %%
# read csv as dataframe as store it into df variable
df = pd.read_csv("mckinsey.csv")

# %%
df.head() # first 5 elements of df
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.head(20)
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 0   Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1   Afghanistan  1957     9240934      Asia    30.332   820.853030
# 2   Afghanistan  1962    10267083      Asia    31.997   853.100710
# 3   Afghanistan  1967    11537966      Asia    34.020   836.197138
# 4   Afghanistan  1972    13079460      Asia    36.088   739.981106
# 5   Afghanistan  1977    14880372      Asia    38.438   786.113360
# 6   Afghanistan  1982    12881816      Asia    39.854   978.011439
# 7   Afghanistan  1987    13867957      Asia    40.822   852.395945
# 8   Afghanistan  1992    16317921      Asia    41.674   649.341395
# 9   Afghanistan  1997    22227415      Asia    41.763   635.341351
# 10  Afghanistan  2002    25268405      Asia    42.129   726.734055
# 11  Afghanistan  2007    31889923      Asia    43.828   974.580338
# 12      Albania  1952     1282697    Europe    55.230  1601.056136
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
type(df['year'])
# Out:
# pandas.core.series.Series

# %%
df['year'][4]
# Out:
# 1972

# %%
df['country'][:5]
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
df['country'].head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
df['country', 'year']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('country', 'year')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-eb1343497bde> in <cell line: 1>()
# ----> 1 df['country', 'year']
#
# ...

# %%
cols = ['country', 'year']
df[cols] # this a df
# Out:
#           country  year
# 0     Afghanistan  1952
# 1     Afghanistan  1957
# 2     Afghanistan  1962
# 3     Afghanistan  1967
# 4     Afghanistan  1972
# ...           ...   ...
# 1699     Zimbabwe  1987
# 1700     Zimbabwe  1992
# 1701     Zimbabwe  1997
# 1702     Zimbabwe  2002
# 1703     Zimbabwe  2007
#
# [1704 rows x 2 columns]

# %%
df[['country']]
# Out:
#           country
# 0     Afghanistan
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# ...           ...
# 1699     Zimbabwe
# 1700     Zimbabwe
# 1701     Zimbabwe
# 1702     Zimbabwe
# 1703     Zimbabwe
#
# [1704 rows x 1 columns]

# %%
df['year']
# Out:
# 0       1952
# 1       1957
# 2       1962
# 3       1967
# 4       1972
#         ...
# 1699    1987
# 1700    1992
# 1701    1997
# 1702    2002
# 1703    2007
# Name: year, Length: 1704, dtype: int64

# %%
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %% [markdown]
# ### Creating DF from scratch:
# https://colab.research.google.com/drive/1x3ct95RtIIQTJeGbyuuYaMociVp90ww6?usp=sharing

# %%
dict_users = {
                "userid":[1, 2, 3, 4],
                "name":["sharadh", "shahid", "khusalli", None]
              }

type(dict_users)
# Out:
# dict

# %%
pd.DataFrame(dict_users)
# Out:
#    userid      name
# 0       1   sharadh
# 1       2    shahid
# 2       3  khusalli
# 3       4      None

# %% [markdown]
# # Columns

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.keys()
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df[['country']]
# Out:
#           country
# 0     Afghanistan
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# ...           ...
# 1699     Zimbabwe
# 1700     Zimbabwe
# 1701     Zimbabwe
# 1702     Zimbabwe
# 1703     Zimbabwe
#
# [1704 rows x 1 columns]

# %% [markdown]
# ### Unique values in series

# %%
df['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
len(df['country'].unique())
# Out:
# 142

# %%
df['country'].nunique()
# Out:
# 142

# %%
df['continent'].value_counts()
# Out:
# continent
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: count, dtype: int64

# %%
df.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-84bc62f43960> in <cell line: 1>()
# ----> 1 df.unique()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %% [markdown]
# ### Rename columns
# We can rename the column by
#
# 1) passing the dictionary with old_name:new_name pair
#
# 2) specifying axis=1

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
dict1 = {"population": "countofpeople", "life_exp": "life_expectancy"}

# %%
df.rename(columns=dict1)  # rename the column index
# Out:
#           country  year  countofpeople continent  life_expectancy     gdp_cap
# 0     Afghanistan  1952        8425333      Asia           28.801  779.445314
# 1     Afghanistan  1957        9240934      Asia           30.332  820.853030
# 2     Afghanistan  1962       10267083      Asia           31.997  853.100710
# 3     Afghanistan  1967       11537966      Asia           34.020  836.197138
# 4     Afghanistan  1972       13079460      Asia           36.088  739.981106
# ...           ...   ...            ...       ...              ...         ...
# 1699     Zimbabwe  1987        9216418    Africa           62.351  706.157306
# 1700     Zimbabwe  1992       10704340    Africa           60.377  693.420786
# 1701     Zimbabwe  1997       11404948    Africa           46.809  792.449960
# 1702     Zimbabwe  2002       11926563    Africa           39.989  672.038623
# 1703     Zimbabwe  2007       12311143    Africa           43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename(dict1, axis = 1)  # rename the column index
# Out:
#           country  year  countofpeople continent  life_expectancy     gdp_cap
# 0     Afghanistan  1952        8425333      Asia           28.801  779.445314
# 1     Afghanistan  1957        9240934      Asia           30.332  820.853030
# 2     Afghanistan  1962       10267083      Asia           31.997  853.100710
# 3     Afghanistan  1967       11537966      Asia           34.020  836.197138
# 4     Afghanistan  1972       13079460      Asia           36.088  739.981106
# ...           ...   ...            ...       ...              ...         ...
# 1699     Zimbabwe  1987        9216418    Africa           62.351  706.157306
# 1700     Zimbabwe  1992       10704340    Africa           60.377  693.420786
# 1701     Zimbabwe  1997       11404948    Africa           46.809  792.449960
# 1702     Zimbabwe  2002       11926563    Africa           39.989  672.038623
# 1703     Zimbabwe  2007       12311143    Africa           43.487  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# ### Create a new column
# 1) Use existing column to create a new col
#
# 2) Create new col from new data

# %%
df['year'] + 10  # create a new series using existing series
# Out:
# 0       1962
# 1       1967
# 2       1972
# 3       1977
# 4       1982
#         ...
# 1699    1997
# 1700    2002
# 1701    2007
# 1702    2012
# 1703    2017
# Name: year, Length: 1704, dtype: int64

# %%
# df['newcolname'] = series/array/list of same size
df['year+10'] = df['year'] + 10

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap  year+10
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314     1962
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030     1967
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710     1972
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138     1977
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106     1982

# %%
# delete a column: axis = 1
df.drop('year+10', axis=1)
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# resume 8:28

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap  year+10
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314     1962
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030     1967
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710     1972
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138     1977
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106     1982
# ...           ...   ...         ...       ...       ...         ...      ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306     1997
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786     2002
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960     2007
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623     2012
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298     2017
#
# [1704 rows x 7 columns]

# %%
# option 1
df2 = df.drop('year+10', axis=1) # return new df with col dropped
df2.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap  year+10
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314     1962
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030     1967
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710     1972
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138     1977
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106     1982

# %%
df.drop('year+10', axis=1, inplace = True)

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %% [markdown]
# ### Q for break:
#
# - remove year + 10 from df completely
# - try overwriting existing column

# %%
# 2) create a new column from scratch
list1 = ["Sachin"]
df["User"] = list1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-e64e0bc5f13a> in <cell line: 3>()
#       1 # 2) create a new column from scratch
#       2 list1 = ["Sachin"]
# ----> 3 df["User"] = list1
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4089         else:
#    4090             # set column
# -> 4091             self._set_item(key, value)
#    4092
#    4093     def _setitem_slice(self, key: slice, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4298         ensure homogeneity.
#    4299         """
# -> 4300         value, refs = self._sanitize_column(value)
#    4301
#    4302         if (
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    5037
#    5038         if is_list_like(value):
# ...

# %%
# creating new col User
new_list = ["Sachin" for i in range(df.shape[0])]
df["User"] = new_list
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap    User
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314  Sachin
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030  Sachin
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710  Sachin
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138  Sachin
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106  Sachin

# %%
df['year2'] = df['year']
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap      User  \
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314  Sachin 0
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030  Sachin 1
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710  Sachin 2
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138  Sachin 3
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106  Sachin 4
#
#    year2
# 0   1952
# 1   1957
# 2   1962
# 3   1967
# 4   1972

# %%
# overwrite col user
new_list = [f"Sachin {i}" for i in range(df.shape[0])]
df["User"] = new_list
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap      User
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314  Sachin 0
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030  Sachin 1
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710  Sachin 2
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138  Sachin 3
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106  Sachin 4

# %%
df['year'] + df['population'] # element wise operation on two series
# Out:
# 0        8427285
# 1        9242891
# 2       10269045
# 3       11539933
# 4       13081432
#           ...
# 1699     9218405
# 1700    10706332
# 1701    11406945
# 1702    11928565
# 1703    12313150
# Length: 1704, dtype: int64

# %%
df.columns[:5]
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp'], dtype='object')

# %% [markdown]
# Given a dataframe consisting of 5 columns

# %%
# df.drop(df.columns[2], axis=1)
# df.drop(df.columns[-3], axis=1)

# %% [markdown]
# - while creating or reading df from scratch, there can be duplicate headers

# %% [markdown]
# ### operation on row indexes

# %%
df.index # access row index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
# let's overwrite row index
df.index = [i + 100 for i in range(df.shape[0])]
df.index
# Out:
# Index([ 100,  101,  102,  103,  104,  105,  106,  107,  108,  109,
#        ...
#        1794, 1795, 1796, 1797, 1798, 1799, 1800, 1801, 1802, 1803],
#       dtype='int64', length=1704)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap  \
# 100   Afghanistan  1952     8425333      Asia    28.801  779.445314
# 101   Afghanistan  1957     9240934      Asia    30.332  820.853030
# 102   Afghanistan  1962    10267083      Asia    31.997  853.100710
# 103   Afghanistan  1967    11537966      Asia    34.020  836.197138
# 104   Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1799     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1800     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1801     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1802     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1803     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
#              User  year2
# 100      Sachin 0   1952
# 101      Sachin 1   1957
# 102      Sachin 2   1962
# 103      Sachin 3   1967
# ...

# %%
df[104] # defaults to column lookup
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 104
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-e6cad4a358d1> in <cell line: 1>()
# ----> 1 df[104] # defaults to column lookup
#
# ...

# %% [markdown]
# explicit: user defined indexing

# %%
df.loc[103] # row lookup: explicit index 4 row from top
# Out:
# country       Afghanistan
# year                 1967
# population       11537966
# continent            Asia
# life_exp            34.02
# gdp_cap        836.197138
# User             Sachin 3
# year2                1967
# Name: 103, dtype: object

# %% [markdown]
# # iloc: implicit indexing
# - standard python style index
#
# # implicit: pre-defined/inbuilt

# %%
df.iloc[3] # row lookup using implicit: inbuilt
# Out:
# country       Afghanistan
# year                 1967
# population       11537966
# continent            Asia
# life_exp            34.02
# gdp_cap        836.197138
# User             Sachin 3
# year2                1967
# Name: 103, dtype: object

# %% [markdown]
# Can we slicing using loc and iloc

# %%
df.loc[101: 104] # in slicing with loc, end is included
# Out:
#          country  year  population continent  life_exp     gdp_cap      User  \
# 101  Afghanistan  1957     9240934      Asia    30.332  820.853030  Sachin 1
# 102  Afghanistan  1962    10267083      Asia    31.997  853.100710  Sachin 2
# 103  Afghanistan  1967    11537966      Asia    34.020  836.197138  Sachin 3
# 104  Afghanistan  1972    13079460      Asia    36.088  739.981106  Sachin 4
#
#      year2
# 101   1957
# 102   1962
# 103   1967
# 104   1972

# %%
df.iloc[1: 4] # in slicing with loc, end is not included
# Out:
#          country  year  population continent  life_exp     gdp_cap      User  \
# 101  Afghanistan  1957     9240934      Asia    30.332  820.853030  Sachin 1
# 102  Afghanistan  1962    10267083      Asia    31.997  853.100710  Sachin 2
# 103  Afghanistan  1967    11537966      Asia    34.020  836.197138  Sachin 3
#
#      year2
# 101   1957
# 102   1962
# 103   1967

# %%
df.loc[101: 104][['population' , 'country']]
# Out:
#      population      country
# 101     9240934  Afghanistan
# 102    10267083  Afghanistan
# 103    11537966  Afghanistan
# 104    13079460  Afghanistan

# %%
df.loc[101: 104, ['population' , 'country']]
# Out:
#      population      country
# 101     9240934  Afghanistan
# 102    10267083  Afghanistan
# 103    11537966  Afghanistan
# 104    13079460  Afghanistan

# %%
df.head()
# Out:
#          country  year  population continent  life_exp     gdp_cap      User  \
# 100  Afghanistan  1952     8425333      Asia    28.801  779.445314  Sachin 0
# 101  Afghanistan  1957     9240934      Asia    30.332  820.853030  Sachin 1
# 102  Afghanistan  1962    10267083      Asia    31.997  853.100710  Sachin 2
# 103  Afghanistan  1967    11537966      Asia    34.020  836.197138  Sachin 3
# 104  Afghanistan  1972    13079460      Asia    36.088  739.981106  Sachin 4
#
#      year2
# 100   1952
# 101   1957
# 102   1962
# 103   1967
# 104   1972

# %%
df.loc[101: 104, 'country':'population']
# Out:
#          country  year  population
# 101  Afghanistan  1957     9240934
# 102  Afghanistan  1962    10267083
# 103  Afghanistan  1967    11537966
# 104  Afghanistan  1972    13079460

# %%
df.iloc[1: 5, 0:3]
# Out:
#          country  year  population
# 101  Afghanistan  1957     9240934
# 102  Afghanistan  1962    10267083
# 103  Afghanistan  1967    11537966
# 104  Afghanistan  1972    13079460

# %%
demo = pd.Series(['a','b','c','d','e'], index=[1,5,3,7,3])
demo
# Out:
# 1    a
# 5    b
# 3    c
# 7    d
# 3    e
# dtype: object

# %%
demo.loc[1]
# Out:
# 'a'

# %%
demo.loc[3]
# Out:
# 3    c
# 3    e
# dtype: object

# %%
demo.loc[1:3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-103-3982b77eccbc> in <cell line: 1>()
# ----> 1 demo.loc[1:3]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1151
#    1152             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153             return self._getitem_axis(maybe_callable, axis=axis)
#    1154
#    1155     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1371         if isinstance(key, slice):
#    1372             self._validate_key(key, axis)
# -> 1373             return self._get_slice_axis(key, axis=axis)
#    1374         elif com.is_bool_indexer(key):
#    1375             return self._getbool_axis(key, axis=axis)
#
# ...

# %% [markdown]
# How to select records from 30th to 40th row for the last 3 columns using iloc?

# %%
df.iloc[29:40, -3:]
# Out:
#          gdp_cap       User  year2
# 129  4910.416756  Sachin 29   1977
# 130  5745.160213  Sachin 30   1982
# 131  5681.358539  Sachin 31   1987
# 132  5023.216647  Sachin 32   1992
# 133  4797.295051  Sachin 33   1997
# 134  5288.040382  Sachin 34   2002
# 135  6223.367465  Sachin 35   2007
# 136  3520.610273  Sachin 36   1952
# 137  3827.940465  Sachin 37   1957
# 138  4269.276742  Sachin 38   1962
# 139  5522.776375  Sachin 39   1967

# %%
a = pd.Series(['a','b','c'], index=[1,2,2])
print(a[2])
# Out:
# 2    b
# 2    c
# dtype: object

# %% [markdown]
# ### HW:
# 0) Index Setter
# - Set one of the existing Column as index of df
#  set country as index
# - reset index to numerical values
#
#
# 1) Add the following row at the end into DataFrame:
#
# ```
# new_row = {'country': 'India', 'year': 2000,'population':13500000, 'continent': "Asia", 'life_exp':37.08, 'gdp_cap':900.23}
# ```
#
# 2) Select a subset of Dataframe containing only first 4 rows and first 3 columns?(HINT: SAME AS SLICING IN 2D Numpy Array
#
# 3) Select All datapoints where life_exp > 50
# (HINT: MASKING IN 2D Numpy Array)
#
# 4) Select all records of the country with Highest Life Expectancy in Asia Continent

# %%
demo = pd.Series(['a','b','c','d','e'], index=[1,5,3,7,3])
demo
# Out:
# 1    a
# 5    b
# 3    c
# 7    d
# 3    e
# dtype: object

# %%
demo.loc[5], demo[5] # use explicit index
# Out:
# ('b', 'b')

# %%
demo.loc[3], demo[3]  # use explicit index
# Out:
# (3    c
#  3    e
#  dtype: object,
#  3    c
#  3    e
#  dtype: object)

# %%
demo.iloc[3]
# Out:
# 'd'

# %% [markdown]
# implicit can't be duplicated

# %% [markdown]
# - aws s3: cloud storage
# - aws efs
# - parquet files stored in local as well cloud
# - query that dumpy data from db to some location
# - blobstorage

# %%
# conditional generation
new_list=["Sachin" if (i%2==0) else "Naveen" for i in range(df.shape[0]) ]
len(new_list)
# Out:
# 1704

# %%
df["User"]=new_list
df.head()
# Out:
#          country  year  population continent  life_exp     gdp_cap    User  \
# 100  Afghanistan  1952     8425333      Asia    28.801  779.445314  Sachin
# 101  Afghanistan  1957     9240934      Asia    30.332  820.853030  Naveen
# 102  Afghanistan  1962    10267083      Asia    31.997  853.100710  Sachin
# 103  Afghanistan  1967    11537966      Asia    34.020  836.197138  Naveen
# 104  Afghanistan  1972    13079460      Asia    36.088  739.981106  Sachin
#
#      year2
# 100   1952
# 101   1957
# 102   1962
# 103   1967
# 104   1972

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap    User  \
# 100   Afghanistan  1952     8425333      Asia    28.801  779.445314  Sachin
# 101   Afghanistan  1957     9240934      Asia    30.332  820.853030  Naveen
# 102   Afghanistan  1962    10267083      Asia    31.997  853.100710  Sachin
# 103   Afghanistan  1967    11537966      Asia    34.020  836.197138  Naveen
# 104   Afghanistan  1972    13079460      Asia    36.088  739.981106  Sachin
# ...           ...   ...         ...       ...       ...         ...     ...
# 1799     Zimbabwe  1987     9216418    Africa    62.351  706.157306  Naveen
# 1800     Zimbabwe  1992    10704340    Africa    60.377  693.420786  Sachin
# 1801     Zimbabwe  1997    11404948    Africa    46.809  792.449960  Naveen
# 1802     Zimbabwe  2002    11926563    Africa    39.989  672.038623  Sachin
# 1803     Zimbabwe  2007    12311143    Africa    43.487  469.709298  Naveen
#
#       year2
# 100    1952
# 101    1957
# 102    1962
# ...

# %%
df.shape # rows and cols
# Out:
# (1704, 8)

# %%
df.shape[0]
# Out:
# 1704

# %%
df.shape[1]
# Out:
# 8

# %%
import numpy as np
arr = np.array([[1,2, 3],
          [4,5,6]])

# %%
arr[0]
# Out:
# array([1, 2, 3])

# %%
arr[1]
# Out:
# array([4, 5, 6])

# %%
np.mean(arr, axis=0) # rowswise mean: mean on columns
# Out:
# array([2.5, 3.5, 4.5])

# %%
arr[0][0], arr[1][0]
# Out:
# (1, 4)

# %%
# 3 2
# 1 2
# 3 4
# 5 6

# # 4 x 2
# # (4 + 2) x (3 + 2) -> filled with zeroes

# %%
arr3 = np.array([[[0, 1],
             [2, 3]],

            [[4, 5],
             [6, 7]]])
arr3[0][0]
# Out:
# array([0, 1])

# %% [markdown]
# [[0, 1],
#              [2, 3]]

# %%
arr2 =    np.array( [[0, 1],
             [2, 3]])

# %%
arr2[0]
# Out:
# array([0, 1])

# %%
list1 = [2,3,4,5]
list1[-1], list1[:-1]
# Out:
# (5, [2, 3, 4])

# %%
list1[0], list1[1:] = list1[-1], list1[:-1] # cyclic swap

# %%
list1
# Out:
# [5, 2, 3, 4]

# %%
arr3 = np.array([[[0, 1],
                 [2, 3]],  # index 0

                  [[4, 5],
                    [6, 7]]] ) # index 1
arr3[0]
# Out:
# array([[0, 1],
#        [2, 3]])

# %%
arr3[0][0]
# Out:
# array([0, 1])

# %%
arr3[0][0][1]
# Out:
# 1

# %%
arr3[1,:, :]
# Out:
# array([[4, 5],
#        [6, 7]])
