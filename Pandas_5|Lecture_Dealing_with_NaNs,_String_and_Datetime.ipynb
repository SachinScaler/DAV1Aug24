# %% [markdown]
# <a href="https://colab.research.google.com/github/SachinScaler/DAV1Aug24/blob/main/Pandas_5%7CLecture_Dealing_with_NaNs%2C_String_and_Datetime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown 173A59xh2mnpmljCCB9bhC4C5eP2IS6qZ
import pandas as pd
import numpy as np

data = pd.read_csv('Pfizer_1.csv')

data_melt = pd.melt(data,id_vars = ['Date', 'Drug_Name', 'Parameter'],
            var_name = "time",
            value_name = 'reading')

data_tidy = data_melt.pivot(index=['Date','time', 'Drug_Name'],
                                        columns = 'Parameter',
                                        values='reading')
data_tidy = data_tidy.reset_index()
data_tidy.columns.name = None
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=173A59xh2mnpmljCCB9bhC4C5eP2IS6qZ
# To: /content/Pfizer_1.csv
# 100% 1.51k/1.51k [00:00<00:00, 4.52MB/s]

# %%
data_tidy.head()
# Out:
#          Date      time                Drug_Name  Pressure  Temperature
# 0  15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1  15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2  15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3  15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4  15-10-2020  11:30:00      docetaxel injection      29.0         25.0

# %%
data_tidy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         108 non-null    object
#  1   time         108 non-null    object
#  2   Drug_Name    108 non-null    object
#  3   Pressure     95 non-null     float64
#  4   Temperature  95 non-null     float64
# dtypes: float64(2), object(3)
# memory usage: 4.3+ KB

# %%
a = None
print(type(a))
# Out:
# <class 'NoneType'>

# %%
import numpy as np

b = np.nan
print(type(b))
# Out:
# <class 'float'>

# %%
pd.Series([1, 2, np.nan])
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
pd.Series([1, 2, 3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series([1, 2, 3.0])
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# dtype: float64

# %%
pd.Series([1, 2, np.nan, None])
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    NaN
# dtype: float64

# %%
pd.Series(["1", "2", None])
# Out:
# 0       1
# 1       2
# 2    None
# dtype: object

# %%
pd.Series(["1", "2", None, np.nan])
# Out:
# 0       1
# 1       2
# 2    None
# 3     NaN
# dtype: object

# %% [markdown]
# ### Detecting Null Values in DF and Column

# %%
num_series = pd.Series([1, 2, np.nan, None])

# %%
num_series.isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# dtype: bool

# %%
num_series.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# dtype: bool

# %%
obj_series = pd.Series(["1", "2", None, np.nan])

# %%
obj_series.isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# dtype: bool

# %%
obj_series.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# dtype: bool

# %%
obj_series.isnull().value_counts()
# Out:
# False    2
# True     2
# Name: count, dtype: int64

# %%
obj_series.isnull().sum() # count of Trues i.e Missing Values
# Out:
# 2

# %% [markdown]
# Missing Vals on Df

# %%
data_tidy.head()
# Out:
#          Date      time                Drug_Name  Pressure  Temperature
# 0  15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1  15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2  15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3  15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4  15-10-2020  11:30:00      docetaxel injection      29.0         25.0

# %%
data_tidy['Pressure'].isna().sum()
# Out:
# 13

# %%
data_tidy.isna()
# Out:
#       Date   time  Drug_Name  Pressure  Temperature
# 0    False  False      False     False        False
# 1    False  False      False     False        False
# 2    False  False      False     False        False
# 3    False  False      False     False        False
# 4    False  False      False     False        False
# ..     ...    ...        ...       ...          ...
# 103  False  False      False     False        False
# 104  False  False      False     False        False
# 105  False  False      False     False        False
# 106  False  False      False     False        False
# 107  False  False      False     False        False
#
# [108 rows x 5 columns]

# %%
# colwise sum
data_tidy.isna().sum()
# Out:
# Date            0
# time            0
# Drug_Name       0
# Pressure       13
# Temperature    13
# dtype: int64

# %%
data_tidy.isna().sum()/len(data_tidy) * 100
# Out:
# Date            0.000000
# time            0.000000
# Drug_Name       0.000000
# Pressure       12.037037
# Temperature    12.037037
# dtype: float64

# %%
len(data_tidy), data_tidy.shape[0]
# Out:
# (108, 108)

# %%
# rowwise count
data_tidy.isna().sum(axis = 1)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 103    0
# 104    0
# 105    0
# 106    0
# 107    0
# Length: 108, dtype: int64

# %% [markdown]
# #### Extract the rows with missing value in a new DF

# %%
pd.isna
# Out:
# <function pandas.core.dtypes.missing.isna(obj: 'object') -> 'bool | npt.NDArray[np.bool_] | NDFrame'>

# %%
pd.isnull
# Out:
# <function pandas.core.dtypes.missing.isna(obj: 'object') -> 'bool | npt.NDArray[np.bool_] | NDFrame'>

# %% [markdown]
# ### Handle Data
# - removing
# - imputing/replacing

# %% [markdown]
# ### Removing Missing Values

# %%
data_tidy.shape
# Out:
# (108, 5)

# %%
data_tidy.head()
# Out:
#          Date      time                Drug_Name  Pressure  Temperature
# 0  15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1  15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2  15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3  15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4  15-10-2020  11:30:00      docetaxel injection      29.0         25.0

# %%
data_drop_axis0 = data_tidy.dropna() # rows with missing values are dropped
data_drop_axis0
# Out:
#            Date      time                Drug_Name  Pressure  Temperature
# 0    15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1    15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2    15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3    15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4    15-10-2020  11:30:00      docetaxel injection      29.0         25.0
# ..          ...       ...                      ...       ...          ...
# 103  17-10-2020   8:30:00      docetaxel injection      26.0         19.0
# 104  17-10-2020   8:30:00   ketamine hydrochloride      11.0         20.0
# 105  17-10-2020   9:30:00  diltiazem hydrochloride       9.0         13.0
# 106  17-10-2020   9:30:00      docetaxel injection      27.0         20.0
# 107  17-10-2020   9:30:00   ketamine hydrochloride      12.0         21.0
#
# [95 rows x 5 columns]

# %%
data_drop_axis0.shape
# Out:
# (95, 5)

# %%
data_drop_axis1 = data_tidy.dropna(axis = 1) # cols with missing values are dropped
data_drop_axis1
# Out:
#            Date      time                Drug_Name
# 0    15-10-2020  10:30:00  diltiazem hydrochloride
# 1    15-10-2020  10:30:00      docetaxel injection
# 2    15-10-2020  10:30:00   ketamine hydrochloride
# 3    15-10-2020  11:30:00  diltiazem hydrochloride
# 4    15-10-2020  11:30:00      docetaxel injection
# ..          ...       ...                      ...
# 103  17-10-2020   8:30:00      docetaxel injection
# 104  17-10-2020   8:30:00   ketamine hydrochloride
# 105  17-10-2020   9:30:00  diltiazem hydrochloride
# 106  17-10-2020   9:30:00      docetaxel injection
# 107  17-10-2020   9:30:00   ketamine hydrochloride
#
# [108 rows x 3 columns]

# %%
data_drop_axis1.shape
# Out:
# (108, 3)

# %% [markdown]
# issue with dropping:
#  - lots of valuable info might get deleted

# %% [markdown]
# ### Imputing Data
# #### Handling Missing Values

# %%
data_0 = data_tidy.fillna(0)
data_0.isna().sum()
# Out:
# Date           0
# time           0
# Drug_Name      0
# Pressure       0
# Temperature    0
# dtype: int64

# %%
data_tidy['Pressure'].isna().sum()
# Out:
# 13

# %%
data_tidy['Temperature'].isna().sum()
# Out:
# 13

# %%
data_tidy['Pressure'].fillna(0)
# Out:
# 0      18.0
# 1      26.0
# 2       9.0
# 3      19.0
# 4      29.0
#        ...
# 103    26.0
# 104    11.0
# 105     9.0
# 106    27.0
# 107    12.0
# Name: Pressure, Length: 108, dtype: float64

# %%
data_tidy['Temperature'].fillna(-9999999999)
# Out:
# 0      20.0
# 1      23.0
# 2      22.0
# 3      20.0
# 4      25.0
#        ...
# 103    19.0
# 104    20.0
# 105    13.0
# 106    20.0
# 107    21.0
# Name: Temperature, Length: 108, dtype: float64

# %% [markdown]
# ## common imputation terms:
#  - fixed values
#
#  ### statistical terms
#  - mean: when data is equally distributed with no Outliers
#  - median: When data has Outliers
#  - mode: Categorical data

# %% [markdown]
# ### Read Doc of Fillna and replace values with mean, median and mode for pressure

# %%
#resume@8:22

# %%
data_tidy['Pressure'].mean()
# Out:
# 17.568421052631578

# %%
data_tidy['Pressure'].median()
# Out:
# 17.0

# %%
data_tidy['Pressure'].mode()
# Out:
# 0    22.0
# Name: Pressure, dtype: float64

# %%
data_tidy['Pressure'].mode().to_list() # series to list
# Out:
# [22.0]

# %%
data_tidy['Pressure'].mode().values # series to array
# Out:
# array([22.])

# %%
data_tidy['Pressure'].mode().to_list()[0]
# Out:
# 22.0

# %%
data_tidy['Pressure'].mode().values[0]
# Out:
# 22.0

# %% [markdown]
# # values on series extract the values as numpy array

# %%
data_tidy['Pressure'].values
# Out:
# array([18., 26.,  9., 19., 29.,  9., 20., 28., 11., 12., nan,  8., 13.,
#        22., nan, nan, 22., nan, 11., nan,  7., 13., 22., nan, 14., 23.,
#         9., 16., nan, 10., 16., nan, 11., 24., 27., 10., 24., 28., 16.,
#        nan, 29., 17., 27., 30., 18., 18., 23., 12., 19., 24., 12., 20.,
#        nan, 13., 21., 25., nan, 22., 26., 15., 23., 27., 15., 24., 28.,
#        15., 25., 29., 15., 25., 28., nan, 11., 28., 13., 13., 29., 14.,
#        14., 28., 15.,  3., 20.,  8.,  4., 22.,  9.,  4., 22., 10.,  4.,
#        22., 11.,  6., 22., 11.,  8., 23., 12.,  9., 25., 12., nan, 26.,
#        11.,  9., 27., 12.])

# %%
mo =  data_tidy['Pressure'].mode().values[0]
data_tidy['Pressure'].fillna(mo)
# Out:
# 0      18.0
# 1      26.0
# 2       9.0
# 3      19.0
# 4      29.0
#        ...
# 103    26.0
# 104    11.0
# 105     9.0
# 106    27.0
# 107    12.0
# Name: Pressure, Length: 108, dtype: float64

# %%
mask = data_tidy['Pressure'].isna()

data_tidy['Pressure'].fillna(mo)[mask]
# Out:
# 10     22.0
# 14     22.0
# 15     22.0
# 17     22.0
# 19     22.0
# 23     22.0
# 28     22.0
# 31     22.0
# 39     22.0
# 52     22.0
# 56     22.0
# 71     22.0
# 102    22.0
# Name: Pressure, dtype: float64

# %%
data_tidy['Pressure'].fillna(mo).isna().sum()
# Out:
# 0

# %%
sample = pd.Series(['1', '2', '3', np.NaN, None])
sample.fillna(0)
# Out:
# 0    1
# 1    2
# 2    3
# 3    0
# 4    0
# dtype: object

# %%
sample
# Out:
# 0       1
# 1       2
# 2       3
# 3     NaN
# 4    None
# dtype: object

# %%
# sample = sample.fillna(0)
sample.fillna(0, inplace = True)

# %%
sample
# Out:
# 0    1
# 1    2
# 2    3
# 3    0
# 4    0
# dtype: object

# %% [markdown]
# Based on the given DataFrame, which of the following statements regarding data imputation is mostly accurate?
#
# |   CustomerID   |  TransactionAmount  |     Gender     |  Age  |  ProductCategory  |
# |----------------|---------------------|----------------|-------|-------------------|
# |       101      |         20          |     Male       |   35  |       Apparel     |
# |       102      |        NaN          |     Female     |   28  |       NaN         |
# |       103      |         15          |     Female     |  NaN  |       Electronics |
# |       104      |         30          |     NaN        |   42  |       Electronics |
# |       105      |        150          |     Male       |   30  |       Apparel     |
# 30 users have participated
#
# - A: Imputing missing values in the "TransactionAmount" column using the mean of the available values may not be suitable due to potential skewness caused by outliers.
# 13%
# - B: Imputing missing values in the "TransactionAmount" column using the median of the available values may be suitable to handle skewness due to outliers.
# 13%
# - C: The presence of missing values in the "Gender" column can be effectively handled by imputing the most frequent category (mode).
# 10%
# - D: All of the above

# %%
# df['Gender'].fillna("Undisclosed")

# %% [markdown]
# ### String

# %%
data_tidy
# Out:
#            Date      time                Drug_Name  Pressure  Temperature
# 0    15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1    15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2    15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3    15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4    15-10-2020  11:30:00      docetaxel injection      29.0         25.0
# ..          ...       ...                      ...       ...          ...
# 103  17-10-2020   8:30:00      docetaxel injection      26.0         19.0
# 104  17-10-2020   8:30:00   ketamine hydrochloride      11.0         20.0
# 105  17-10-2020   9:30:00  diltiazem hydrochloride       9.0         13.0
# 106  17-10-2020   9:30:00      docetaxel injection      27.0         20.0
# 107  17-10-2020   9:30:00   ketamine hydrochloride      12.0         21.0
#
# [108 rows x 5 columns]

# %%
data_tidy['Drug_Name'].apply(lambda x : 'hydrochloride' in x)
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 103    False
# 104     True
# 105     True
# 106    False
# 107     True
# Name: Drug_Name, Length: 108, dtype: bool

# %%
data_tidy['Drug_Name'].str.contains('hydrochloride')
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 103    False
# 104     True
# 105     True
# 106    False
# 107     True
# Name: Drug_Name, Length: 108, dtype: bool

# %%
sum([True, True, False])
# Out:
# 2

# %%
data_tidy['Drug_Name']
# Out:
# 0      diltiazem hydrochloride
# 1          docetaxel injection
# 2       ketamine hydrochloride
# 3      diltiazem hydrochloride
# 4          docetaxel injection
#                 ...
# 103        docetaxel injection
# 104     ketamine hydrochloride
# 105    diltiazem hydrochloride
# 106        docetaxel injection
# 107     ketamine hydrochloride
# Name: Drug_Name, Length: 108, dtype: object

# %%
data_tidy['Date']
# Out:
# 0      15-10-2020
# 1      15-10-2020
# 2      15-10-2020
# 3      15-10-2020
# 4      15-10-2020
#           ...
# 103    17-10-2020
# 104    17-10-2020
# 105    17-10-2020
# 106    17-10-2020
# 107    17-10-2020
# Name: Date, Length: 108, dtype: object

# %%
data_tidy['Date'].str.split('-')
# Out:
# 0      [15, 10, 2020]
# 1      [15, 10, 2020]
# 2      [15, 10, 2020]
# 3      [15, 10, 2020]
# 4      [15, 10, 2020]
#             ...
# 103    [17, 10, 2020]
# 104    [17, 10, 2020]
# 105    [17, 10, 2020]
# 106    [17, 10, 2020]
# 107    [17, 10, 2020]
# Name: Date, Length: 108, dtype: object

# %%
data_tidy['extractedDate'] = data_tidy['Date'].str.split('-').apply(lambda x: x[1])
data_tidy['extractedDate']
# Out:
# 0      10
# 1      10
# 2      10
# 3      10
# 4      10
#        ..
# 103    10
# 104    10
# 105    10
# 106    10
# 107    10
# Name: extractedDate, Length: 108, dtype: object

# %%
# 15-10-2020 -> 15, 10, 2020

# %%
data_tidy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           108 non-null    object
#  1   time           108 non-null    object
#  2   Drug_Name      108 non-null    object
#  3   Pressure       95 non-null     float64
#  4   Temperature    95 non-null     float64
#  5   extractedDate  108 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 5.2+ KB

# %%
data_tidy['ConvertedDate'] = pd.to_datetime(data_tidy['Date'])
data_tidy['ConvertedDate']
# Out:
# <ipython-input-68-f753e124e9db>:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data_tidy['ConvertedDate'] = pd.to_datetime(data_tidy['Date'])
# 0     2020-10-15
# 1     2020-10-15
# 2     2020-10-15
# 3     2020-10-15
# 4     2020-10-15
#          ...
# 103   2020-10-17
# 104   2020-10-17
# 105   2020-10-17
# 106   2020-10-17
# 107   2020-10-17
# Name: ConvertedDate, Length: 108, dtype: datetime64[ns]

# %%
data_tidy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           108 non-null    object
#  1   time           108 non-null    object
#  2   Drug_Name      108 non-null    object
#  3   Pressure       95 non-null     float64
#  4   Temperature    95 non-null     float64
#  5   extractedDate  108 non-null    object
#  6   ConvertedDate  108 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(4)
# memory usage: 6.0+ KB

# %%
data_tidy['Date'].dt.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-df91bf5d470a> in <cell line: 1>()
# ----> 1 data_tidy['Date'].dt.year
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
#     226         # https://www.pydanny.com/cached-property.html
#
# ...

# %%
data_tidy['ConvertedDate'].dt.year
# Out:
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 103    2020
# 104    2020
# 105    2020
# 106    2020
# 107    2020
# Name: ConvertedDate, Length: 108, dtype: int32

# %%
data_tidy['ConvertedDate'].dt.month
# Out:
# 0      10
# 1      10
# 2      10
# 3      10
# 4      10
#        ..
# 103    10
# 104    10
# 105    10
# 106    10
# 107    10
# Name: ConvertedDate, Length: 108, dtype: int32

# %% [markdown]
# ### Can we convert full time stamp into Datetime

# %%
data_tidy
# Out:
#            Date      time                Drug_Name  Pressure  Temperature  \
# 0    15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1    15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2    15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3    15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4    15-10-2020  11:30:00      docetaxel injection      29.0         25.0
# ..          ...       ...                      ...       ...          ...
# 103  17-10-2020   8:30:00      docetaxel injection      26.0         19.0
# 104  17-10-2020   8:30:00   ketamine hydrochloride      11.0         20.0
# 105  17-10-2020   9:30:00  diltiazem hydrochloride       9.0         13.0
# 106  17-10-2020   9:30:00      docetaxel injection      27.0         20.0
# 107  17-10-2020   9:30:00   ketamine hydrochloride      12.0         21.0
#
#     extractedDate ConvertedDate
# 0              10    2020-10-15
# ...

# %%
data['timestamp'] = data_tidy['Date'] + " " + data_tidy['time']
data['timestamp']
# Out:
# 0     15-10-2020 10:30:00
# 1     15-10-2020 10:30:00
# 2     15-10-2020 10:30:00
# 3     15-10-2020 11:30:00
# 4     15-10-2020 11:30:00
# 5     15-10-2020 11:30:00
# 6     15-10-2020 12:30:00
# 7     15-10-2020 12:30:00
# 8     15-10-2020 12:30:00
# 9      15-10-2020 1:30:00
# 10     15-10-2020 1:30:00
# 11     15-10-2020 1:30:00
# 12     15-10-2020 2:30:00
# 13     15-10-2020 2:30:00
# 14     15-10-2020 2:30:00
# 15     15-10-2020 3:30:00
# 16     15-10-2020 3:30:00
# 17     15-10-2020 3:30:00
# Name: timestamp, dtype: object

# %%
data['timestamp'] = pd.to_datetime(data['timestamp'])
data['timestamp']
# Out:
# <ipython-input-75-b3b362fb0df7>:1: UserWarning: Parsing dates in %d-%m-%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['timestamp'] = pd.to_datetime(data['timestamp'])
# 0    2020-10-15 10:30:00
# 1    2020-10-15 10:30:00
# 2    2020-10-15 10:30:00
# 3    2020-10-15 11:30:00
# 4    2020-10-15 11:30:00
# 5    2020-10-15 11:30:00
# 6    2020-10-15 12:30:00
# 7    2020-10-15 12:30:00
# 8    2020-10-15 12:30:00
# 9    2020-10-15 01:30:00
# 10   2020-10-15 01:30:00
# 11   2020-10-15 01:30:00
# 12   2020-10-15 02:30:00
# 13   2020-10-15 02:30:00
# 14   2020-10-15 02:30:00
# 15   2020-10-15 03:30:00
# 16   2020-10-15 03:30:00
# 17   2020-10-15 03:30:00
# Name: timestamp, dtype: datetime64[ns]

# %%
data['timestamp'].dt.year
# Out:
# 0     2020
# 1     2020
# 2     2020
# 3     2020
# 4     2020
# 5     2020
# 6     2020
# 7     2020
# 8     2020
# 9     2020
# 10    2020
# 11    2020
# 12    2020
# 13    2020
# 14    2020
# 15    2020
# 16    2020
# 17    2020
# Name: timestamp, dtype: int32

# %% [markdown]
# ### HW:
# - comparison
# - sorting
# - subtration and addition

# %%
data['timestamp'][0].strftime('%Y-%m-%d')
# Out:
# '2020-10-15'

# %%
#2020-10-15 -> 2020->Oct-15

# %%
df = pd.DataFrame([[1, '2020-01-01'], [2, '1998-01-12'], [3, '2012-11-05'],
                   [4, '2000-12-03'], [5, '1960-04-23'], [6, '2008-08-15']],
                    columns=["ID", "birth_dates"])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           6 non-null      int64
#  1   birth_dates  6 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 224.0+ bytes

# %%
df.head()
# Out:
#    ID birth_dates
# 0   1  2020-01-01
# 1   2  1998-01-12
# 2   3  2012-11-05
# 3   4  2000-12-03
# 4   5  1960-04-23

# %%
df['birth_dates'] = pd.to_datetime(df['birth_dates'])
df['birth_dates']
# Out:
# 0   2020-01-01
# 1   1998-01-12
# 2   2012-11-05
# 3   2000-12-03
# 4   1960-04-23
# 5   2008-08-15
# Name: birth_dates, dtype: datetime64[ns]

# %%
df.iloc[2]['birth_dates'].year - df.iloc[1]['birth_dates'].year
# Out:
# 14

# %% [markdown]
# ### Write Dataframe into CSV
#
# df.to_csv(pathtowriteat)

# %%
data_tidy.to_csv('/content/my-data-folder/pfizer_tidy_processed.csv',
                 index = False,
                 sep = '\t') # writes the file into new path # tsv

# %%
#pd.read_csv(r"C:\...\...\filename.csv")

# %% [markdown]
# HW: index=True what is the purpose of this parameter

# %%
df2 = pd.read_csv('pfizer_tidy_processed.csv')
df2.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-89-53976c7bd413> in <cell line: 1>()
# ----> 1 df2 = pd.read_csv('/content/my-data-folder/pfizer_tidy_processed.csv')
#       2 df2.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
data_tidy.to_excel('pfizer_tidy_processed.xlsx',
                 index = False)

# %%
df = pd.DataFrame({"SID": [1,1,1,2,2,2],
              "Sub": ["M", "P", "C","M", "P", "C", ],
              "Score": [85, 78, 92, 72, 80, 88]})
df

# %%
import numpy as np
pd.pivot(index = "SID", columns = "Sub", data = df)

# %%
pd.melt(df, id_vars="SID", var_name="Sub")

# %%
pd.melt(df, id_vars="SID")

# %%
# Melting the dataset using 'Student_ID' as the identifier variable and
# 'Subject' as the variable to unpivot,
# then computing the mean of the 'Score' column.
pd.melt(df, id_vars="SID", var_name="Sub")

# %%
pd.melt(df, id_vars="SID")

# %%
df

# %%
import pandas as pd

sales_data = {
    'Date': ['2024-01-01', '2024-01-01', '2024-01-02', '2024-01-02'],
    'Region': ['East', 'West', 'East', 'West'],
    'Product': ['A', 'B', 'A', 'B'],
    'Sales': [100, 200, 150, 250]
}

df = pd.DataFrame(sales_data)
df.head()

# %%
pd.pivot_table(df, index = 'Region', values = 'Sales' , aggfunc = sum)
